# %% [markdown]
# # 第4章
# モデル作成について学ぶ。
#
# ---
# ソースコードは以下から引用しています: https://github.com/ghmagazine/kagglebook/tree/master/ch04
#
# ライセンス: https://github.com/ghmagazine/kagglebook/blob/master/LICENSE

# %% [markdown]
# ## データ準備

# %%
import numpy as np
import pandas as pd

# train_xは学習データ、train_yは目的変数、test_xはテストデータ
# pandasのDataFrame, Seriesで保持します。（numpyのarrayで保持することもあります）

train = pd.read_csv('data/sample-data/train_preprocessed.csv')
train_x = train.drop(['target'], axis=1)
train_y = train['target']
test_x = pd.read_csv('data/sample-data/test_preprocessed.csv')

# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %% [markdown]
# ## lightgbm

# %%
import lightgbm as lgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をlightgbmのデータ構造に変換する
lgb_train = lgb.Dataset(tr_x, tr_y)
lgb_eval = lgb.Dataset(va_x, va_y)

# ハイパーパラメータの設定
params = {'objective': 'binary', 'seed': 71, 'verbose': 0, 'metrics': 'binary_logloss'}
num_round = 300

# 学習の実行
# カテゴリ変数をパラメータで指定している
# バリデーションデータもモデルに渡し、学習の進行とともにスコアがどう変わるかモニタリングする
categorical_features = ['product', 'medical_info_b2', 'medical_info_b3']
model = lgb.train(params, lgb_train, num_boost_round=num_round,
                  categorical_feature=categorical_features,
                  valid_names=['train', 'valid'], valid_sets=[lgb_train, lgb_eval])

# バリデーションデータでのスコアの確認
va_pred = model.predict(va_x)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')

# 予測
pred = model.predict(test_x)
# Out:
# /root/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py:1190: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['medical_info_b2', 'medical_info_b3', 'product']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /root/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py:752: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	train's binary_logloss: 0.454286	valid's binary_logloss: 0.4654
# [2]	train's binary_logloss: 0.429417	valid's binary_logloss: 0.443487
# [3]	train's binary_logloss: 0.410142	valid's binary_logloss: 0.426359
# [4]	train's binary_logloss: 0.393494	valid's binary_logloss: 0.411015
# [5]	train's binary_logloss: 0.379488	valid's binary_logloss: 0.398589
# [6]	train's binary_logloss: 0.366857	valid's binary_logloss: 0.386944
# [7]	train's binary_logloss: 0.354417	valid's binary_logloss: 0.376575
# [8]	train's binary_logloss: 0.34379	valid's binary_logloss: 0.367472
# [9]	train's binary_logloss: 0.334998	valid's binary_logloss: 0.359954
# [10]	train's binary_logloss: 0.325439	valid's binary_logloss: 0.35231
# [11]	train's binary_logloss: 0.316396	valid's binary_logloss: 0.345017
# [12]	train's binary_logloss: 0.309224	valid's binary_logloss: 0.340222
# [13]	train's binary_logloss: 0.301732	valid's binary_logloss: 0.333364
# [14]	train's binary_logloss: 0.294708	valid's binary_logloss: 0.328792
# [15]	train's binary_logloss: 0.288201	valid's binary_logloss: 0.324163
# [16]	train's binary_logloss: 0.282431	valid's binary_logloss: 0.319925
# [17]	train's binary_logloss: 0.276254	valid's binary_logloss: 0.315333
# [18]	train's binary_logloss: 0.271291	valid's binary_logloss: 0.312272
# [19]	train's binary_logloss: 0.265568	valid's binary_logloss: 0.308592
# [20]	train's binary_logloss: 0.260806	valid's binary_logloss: 0.305423
# [21]	train's binary_logloss: 0.256176	valid's binary_logloss: 0.302695
# [22]	train's binary_logloss: 0.251765	valid's binary_logloss: 0.300585
# [23]	train's binary_logloss: 0.247005	valid's binary_logloss: 0.29676
# [24]	train's binary_logloss: 0.242821	valid's binary_logloss: 0.294192
# [25]	train's binary_logloss: 0.23893	valid's binary_logloss: 0.291965
# [26]	train's binary_logloss: 0.234672	valid's binary_logloss: 0.288845
# [27]	train's binary_logloss: 0.230955	valid's binary_logloss: 0.286873
# [28]	train's binary_logloss: 0.227917	valid's binary_logloss: 0.284952
# [29]	train's binary_logloss: 0.22419	valid's binary_logloss: 0.282441
# [30]	train's binary_logloss: 0.220358	valid's binary_logloss: 0.279985
# [31]	train's binary_logloss: 0.216471	valid's binary_logloss: 0.276463
# [32]	train's binary_logloss: 0.213126	valid's binary_logloss: 0.274941
# [33]	train's binary_logloss: 0.209834	valid's binary_logloss: 0.27273
# [34]	train's binary_logloss: 0.206753	valid's binary_logloss: 0.271164
# [35]	train's binary_logloss: 0.204203	valid's binary_logloss: 0.269744
# [36]	train's binary_logloss: 0.200539	valid's binary_logloss: 0.266825
# [37]	train's binary_logloss: 0.197168	valid's binary_logloss: 0.265267
# [38]	train's binary_logloss: 0.194498	valid's binary_logloss: 0.263992
# [39]	train's binary_logloss: 0.192032	valid's binary_logloss: 0.263437
# [40]	train's binary_logloss: 0.189326	valid's binary_logloss: 0.261947
# [41]	train's binary_logloss: 0.186858	valid's binary_logloss: 0.260294
# [42]	train's binary_logloss: 0.18455	valid's binary_logloss: 0.259234
# [43]	train's binary_logloss: 0.181977	valid's binary_logloss: 0.257863
# [44]	train's binary_logloss: 0.179512	valid's binary_logloss: 0.256472
# [45]	train's binary_logloss: 0.177167	valid's binary_logloss: 0.255215
# [46]	train's binary_logloss: 0.174983	valid's binary_logloss: 0.254662
# [47]	train's binary_logloss: 0.172989	valid's binary_logloss: 0.254382
# [48]	train's binary_logloss: 0.170821	valid's binary_logloss: 0.253217
# [49]	train's binary_logloss: 0.168089	valid's binary_logloss: 0.251035
# [50]	train's binary_logloss: 0.16612	valid's binary_logloss: 0.250534
# [51]	train's binary_logloss: 0.164304	valid's binary_logloss: 0.249786
# [52]	train's binary_logloss: 0.162127	valid's binary_logloss: 0.24821
# [53]	train's binary_logloss: 0.160416	valid's binary_logloss: 0.247239
# [54]	train's binary_logloss: 0.158818	valid's binary_logloss: 0.246814
# [55]	train's binary_logloss: 0.156032	valid's binary_logloss: 0.244454
# [56]	train's binary_logloss: 0.154359	valid's binary_logloss: 0.243893
# [57]	train's binary_logloss: 0.152642	valid's binary_logloss: 0.243225
# [58]	train's binary_logloss: 0.151044	valid's binary_logloss: 0.242837
# [59]	train's binary_logloss: 0.149127	valid's binary_logloss: 0.241454
# [60]	train's binary_logloss: 0.146802	valid's binary_logloss: 0.239391
# [61]	train's binary_logloss: 0.145309	valid's binary_logloss: 0.238612
# [62]	train's binary_logloss: 0.143786	valid's binary_logloss: 0.238014
# [63]	train's binary_logloss: 0.142085	valid's binary_logloss: 0.236823
# [64]	train's binary_logloss: 0.140588	valid's binary_logloss: 0.236355
# [65]	train's binary_logloss: 0.138946	valid's binary_logloss: 0.235721
# [66]	train's binary_logloss: 0.137666	valid's binary_logloss: 0.235887
# [67]	train's binary_logloss: 0.135987	valid's binary_logloss: 0.235729
# [68]	train's binary_logloss: 0.134551	valid's binary_logloss: 0.235073
# [69]	train's binary_logloss: 0.133163	valid's binary_logloss: 0.234729
# [70]	train's binary_logloss: 0.131297	valid's binary_logloss: 0.233257
# [71]	train's binary_logloss: 0.12978	valid's binary_logloss: 0.232796
# [72]	train's binary_logloss: 0.128516	valid's binary_logloss: 0.232675
# [73]	train's binary_logloss: 0.12705	valid's binary_logloss: 0.232375
# [74]	train's binary_logloss: 0.12569	valid's binary_logloss: 0.231574
# [75]	train's binary_logloss: 0.124247	valid's binary_logloss: 0.230772
# [76]	train's binary_logloss: 0.122886	valid's binary_logloss: 0.229912
# [77]	train's binary_logloss: 0.121689	valid's binary_logloss: 0.229134
# [78]	train's binary_logloss: 0.120185	valid's binary_logloss: 0.227908
# [79]	train's binary_logloss: 0.119006	valid's binary_logloss: 0.227255
# [80]	train's binary_logloss: 0.117758	valid's binary_logloss: 0.226919
# [81]	train's binary_logloss: 0.116367	valid's binary_logloss: 0.226063
# [82]	train's binary_logloss: 0.115242	valid's binary_logloss: 0.225734
# [83]	train's binary_logloss: 0.114066	valid's binary_logloss: 0.225842
# [84]	train's binary_logloss: 0.113021	valid's binary_logloss: 0.225589
# [85]	train's binary_logloss: 0.111898	valid's binary_logloss: 0.22567
# [86]	train's binary_logloss: 0.110745	valid's binary_logloss: 0.225063
# [87]	train's binary_logloss: 0.109676	valid's binary_logloss: 0.225015
# [88]	train's binary_logloss: 0.10853	valid's binary_logloss: 0.225252
# [89]	train's binary_logloss: 0.107014	valid's binary_logloss: 0.223305
# [90]	train's binary_logloss: 0.105649	valid's binary_logloss: 0.222349
# [91]	train's binary_logloss: 0.10459	valid's binary_logloss: 0.221952
# [92]	train's binary_logloss: 0.103518	valid's binary_logloss: 0.221524
# [93]	train's binary_logloss: 0.102541	valid's binary_logloss: 0.221294
# [94]	train's binary_logloss: 0.101574	valid's binary_logloss: 0.221408
# [95]	train's binary_logloss: 0.100554	valid's binary_logloss: 0.221599
# [96]	train's binary_logloss: 0.0994329	valid's binary_logloss: 0.221159
# [97]	train's binary_logloss: 0.09839	valid's binary_logloss: 0.220885
# [98]	train's binary_logloss: 0.0974307	valid's binary_logloss: 0.22092
# [99]	train's binary_logloss: 0.0965374	valid's binary_logloss: 0.220945
# [100]	train's binary_logloss: 0.0956876	valid's binary_logloss: 0.221081
# [101]	train's binary_logloss: 0.0947192	valid's binary_logloss: 0.220654
# [102]	train's binary_logloss: 0.0937916	valid's binary_logloss: 0.220549
# [103]	train's binary_logloss: 0.0930301	valid's binary_logloss: 0.220399
# [104]	train's binary_logloss: 0.0920165	valid's binary_logloss: 0.219945
# [105]	train's binary_logloss: 0.0910464	valid's binary_logloss: 0.219687
# [106]	train's binary_logloss: 0.0901609	valid's binary_logloss: 0.21969
# [107]	train's binary_logloss: 0.0893582	valid's binary_logloss: 0.219252
# [108]	train's binary_logloss: 0.0885249	valid's binary_logloss: 0.218901
# [109]	train's binary_logloss: 0.0875383	valid's binary_logloss: 0.218721
# [110]	train's binary_logloss: 0.0866552	valid's binary_logloss: 0.218691
# [111]	train's binary_logloss: 0.0856867	valid's binary_logloss: 0.218664
# [112]	train's binary_logloss: 0.0849394	valid's binary_logloss: 0.218769
# [113]	train's binary_logloss: 0.0842242	valid's binary_logloss: 0.218774
# [114]	train's binary_logloss: 0.0830104	valid's binary_logloss: 0.217509
# [115]	train's binary_logloss: 0.0822351	valid's binary_logloss: 0.216948
# [116]	train's binary_logloss: 0.081499	valid's binary_logloss: 0.21661
# [117]	train's binary_logloss: 0.0807778	valid's binary_logloss: 0.216547
# [118]	train's binary_logloss: 0.0800547	valid's binary_logloss: 0.21671
# [119]	train's binary_logloss: 0.0792931	valid's binary_logloss: 0.216854
# [120]	train's binary_logloss: 0.0785995	valid's binary_logloss: 0.216721
# [121]	train's binary_logloss: 0.0777836	valid's binary_logloss: 0.216279
# [122]	train's binary_logloss: 0.0770291	valid's binary_logloss: 0.215768
# [123]	train's binary_logloss: 0.0763529	valid's binary_logloss: 0.215663
# [124]	train's binary_logloss: 0.0756929	valid's binary_logloss: 0.215824
# [125]	train's binary_logloss: 0.0748481	valid's binary_logloss: 0.215032
# [126]	train's binary_logloss: 0.0741879	valid's binary_logloss: 0.214879
# [127]	train's binary_logloss: 0.0736052	valid's binary_logloss: 0.214681
# [128]	train's binary_logloss: 0.0729446	valid's binary_logloss: 0.213922
# [129]	train's binary_logloss: 0.0722322	valid's binary_logloss: 0.213616
# [130]	train's binary_logloss: 0.0715016	valid's binary_logloss: 0.213133
# [131]	train's binary_logloss: 0.070899	valid's binary_logloss: 0.213395
# [132]	train's binary_logloss: 0.0702773	valid's binary_logloss: 0.213331
# [133]	train's binary_logloss: 0.0695678	valid's binary_logloss: 0.212686
# [134]	train's binary_logloss: 0.069043	valid's binary_logloss: 0.212414
# [135]	train's binary_logloss: 0.0684006	valid's binary_logloss: 0.212752
# [136]	train's binary_logloss: 0.0678648	valid's binary_logloss: 0.212819
# [137]	train's binary_logloss: 0.0672611	valid's binary_logloss: 0.21271
# [138]	train's binary_logloss: 0.0666838	valid's binary_logloss: 0.212938
# [139]	train's binary_logloss: 0.066072	valid's binary_logloss: 0.212569
# [140]	train's binary_logloss: 0.0655498	valid's binary_logloss: 0.212612
# [141]	train's binary_logloss: 0.0649604	valid's binary_logloss: 0.212542
# [142]	train's binary_logloss: 0.0643114	valid's binary_logloss: 0.212542
# [143]	train's binary_logloss: 0.0636712	valid's binary_logloss: 0.212273
# [144]	train's binary_logloss: 0.0630001	valid's binary_logloss: 0.211446
# [145]	train's binary_logloss: 0.0623817	valid's binary_logloss: 0.211248
# [146]	train's binary_logloss: 0.0618578	valid's binary_logloss: 0.211539
# [147]	train's binary_logloss: 0.0613503	valid's binary_logloss: 0.211277
# [148]	train's binary_logloss: 0.0607601	valid's binary_logloss: 0.210968
# [149]	train's binary_logloss: 0.0601986	valid's binary_logloss: 0.210897
# [150]	train's binary_logloss: 0.0595744	valid's binary_logloss: 0.210812
# [151]	train's binary_logloss: 0.059031	valid's binary_logloss: 0.21055
# [152]	train's binary_logloss: 0.0583743	valid's binary_logloss: 0.210196
# [153]	train's binary_logloss: 0.0578932	valid's binary_logloss: 0.210519
# [154]	train's binary_logloss: 0.0573391	valid's binary_logloss: 0.210795
# [155]	train's binary_logloss: 0.0568473	valid's binary_logloss: 0.210704
# [156]	train's binary_logloss: 0.0563098	valid's binary_logloss: 0.210547
# [157]	train's binary_logloss: 0.0558139	valid's binary_logloss: 0.210386
# [158]	train's binary_logloss: 0.0552833	valid's binary_logloss: 0.210318
# [159]	train's binary_logloss: 0.0548272	valid's binary_logloss: 0.210245
# [160]	train's binary_logloss: 0.0543163	valid's binary_logloss: 0.210311
# [161]	train's binary_logloss: 0.0538664	valid's binary_logloss: 0.210267
# [162]	train's binary_logloss: 0.0533857	valid's binary_logloss: 0.210163
# [163]	train's binary_logloss: 0.0529452	valid's binary_logloss: 0.210161
# [164]	train's binary_logloss: 0.0524996	valid's binary_logloss: 0.210123
# [165]	train's binary_logloss: 0.0519695	valid's binary_logloss: 0.210117
# [166]	train's binary_logloss: 0.0515136	valid's binary_logloss: 0.210138
# [167]	train's binary_logloss: 0.0510402	valid's binary_logloss: 0.210137
# [168]	train's binary_logloss: 0.0505055	valid's binary_logloss: 0.209715
# [169]	train's binary_logloss: 0.0500879	valid's binary_logloss: 0.209729
# [170]	train's binary_logloss: 0.0496811	valid's binary_logloss: 0.209841
# [171]	train's binary_logloss: 0.0492251	valid's binary_logloss: 0.209993
# [172]	train's binary_logloss: 0.0488387	valid's binary_logloss: 0.210273
# [173]	train's binary_logloss: 0.0483809	valid's binary_logloss: 0.210022
# [174]	train's binary_logloss: 0.0479534	valid's binary_logloss: 0.210315
# [175]	train's binary_logloss: 0.0475905	valid's binary_logloss: 0.210469
# [176]	train's binary_logloss: 0.0470586	valid's binary_logloss: 0.210253
# [177]	train's binary_logloss: 0.0467	valid's binary_logloss: 0.210233
# [178]	train's binary_logloss: 0.0463075	valid's binary_logloss: 0.210251
# [179]	train's binary_logloss: 0.0459462	valid's binary_logloss: 0.21017
# [180]	train's binary_logloss: 0.0455657	valid's binary_logloss: 0.210409
# [181]	train's binary_logloss: 0.0451704	valid's binary_logloss: 0.210291
# [182]	train's binary_logloss: 0.044819	valid's binary_logloss: 0.210134
# [183]	train's binary_logloss: 0.0444309	valid's binary_logloss: 0.210408
# [184]	train's binary_logloss: 0.0439653	valid's binary_logloss: 0.209977
# [185]	train's binary_logloss: 0.0436145	valid's binary_logloss: 0.210068
# [186]	train's binary_logloss: 0.043208	valid's binary_logloss: 0.209889
# [187]	train's binary_logloss: 0.0428601	valid's binary_logloss: 0.210116
# [188]	train's binary_logloss: 0.0424943	valid's binary_logloss: 0.210208
# [189]	train's binary_logloss: 0.042121	valid's binary_logloss: 0.210389
# [190]	train's binary_logloss: 0.0417657	valid's binary_logloss: 0.210134
# [191]	train's binary_logloss: 0.0414265	valid's binary_logloss: 0.210087
# [192]	train's binary_logloss: 0.0410369	valid's binary_logloss: 0.210163
# [193]	train's binary_logloss: 0.0407076	valid's binary_logloss: 0.210132
# [194]	train's binary_logloss: 0.0403809	valid's binary_logloss: 0.209968
# [195]	train's binary_logloss: 0.0400728	valid's binary_logloss: 0.20993
# [196]	train's binary_logloss: 0.0396733	valid's binary_logloss: 0.209878
# [197]	train's binary_logloss: 0.0392792	valid's binary_logloss: 0.209418
# [198]	train's binary_logloss: 0.0388855	valid's binary_logloss: 0.209483
# [199]	train's binary_logloss: 0.0385772	valid's binary_logloss: 0.20944
# [200]	train's binary_logloss: 0.0382351	valid's binary_logloss: 0.209168
# [201]	train's binary_logloss: 0.0379234	valid's binary_logloss: 0.209001
# [202]	train's binary_logloss: 0.0375595	valid's binary_logloss: 0.208953
# [203]	train's binary_logloss: 0.0372687	valid's binary_logloss: 0.208951
# [204]	train's binary_logloss: 0.0369515	valid's binary_logloss: 0.208996
# [205]	train's binary_logloss: 0.0366769	valid's binary_logloss: 0.209282
# [206]	train's binary_logloss: 0.0363834	valid's binary_logloss: 0.209611
# [207]	train's binary_logloss: 0.0360439	valid's binary_logloss: 0.209438
# [208]	train's binary_logloss: 0.035783	valid's binary_logloss: 0.209838
# [209]	train's binary_logloss: 0.0355022	valid's binary_logloss: 0.209576
# [210]	train's binary_logloss: 0.0352215	valid's binary_logloss: 0.209513
# [211]	train's binary_logloss: 0.0348197	valid's binary_logloss: 0.209192
# [212]	train's binary_logloss: 0.0344934	valid's binary_logloss: 0.209516
# [213]	train's binary_logloss: 0.0341897	valid's binary_logloss: 0.209411
# [214]	train's binary_logloss: 0.0338917	valid's binary_logloss: 0.209431
# [215]	train's binary_logloss: 0.0336071	valid's binary_logloss: 0.209281
# [216]	train's binary_logloss: 0.0333096	valid's binary_logloss: 0.209225
# [217]	train's binary_logloss: 0.0329538	valid's binary_logloss: 0.208631
# [218]	train's binary_logloss: 0.0326589	valid's binary_logloss: 0.208375
# [219]	train's binary_logloss: 0.0324045	valid's binary_logloss: 0.208405
# [220]	train's binary_logloss: 0.0321345	valid's binary_logloss: 0.208116
# [221]	train's binary_logloss: 0.0318776	valid's binary_logloss: 0.208216
# [222]	train's binary_logloss: 0.031619	valid's binary_logloss: 0.208274
# [223]	train's binary_logloss: 0.031385	valid's binary_logloss: 0.208616
# [224]	train's binary_logloss: 0.0311371	valid's binary_logloss: 0.208259
# [225]	train's binary_logloss: 0.0309086	valid's binary_logloss: 0.208586
# [226]	train's binary_logloss: 0.0306572	valid's binary_logloss: 0.208635
# [227]	train's binary_logloss: 0.0303986	valid's binary_logloss: 0.20884
# [228]	train's binary_logloss: 0.0301517	valid's binary_logloss: 0.209046
# [229]	train's binary_logloss: 0.0299565	valid's binary_logloss: 0.209064
# [230]	train's binary_logloss: 0.0297136	valid's binary_logloss: 0.209663
# [231]	train's binary_logloss: 0.0294693	valid's binary_logloss: 0.209907
# [232]	train's binary_logloss: 0.0292381	valid's binary_logloss: 0.210121
# [233]	train's binary_logloss: 0.0290099	valid's binary_logloss: 0.210293
# [234]	train's binary_logloss: 0.0288285	valid's binary_logloss: 0.210536
# [235]	train's binary_logloss: 0.0285939	valid's binary_logloss: 0.210816
# [236]	train's binary_logloss: 0.0283761	valid's binary_logloss: 0.210562
# [237]	train's binary_logloss: 0.0280885	valid's binary_logloss: 0.209916
# [238]	train's binary_logloss: 0.0278451	valid's binary_logloss: 0.209959
# [239]	train's binary_logloss: 0.0276138	valid's binary_logloss: 0.210433
# [240]	train's binary_logloss: 0.0273448	valid's binary_logloss: 0.210646
# [241]	train's binary_logloss: 0.0271392	valid's binary_logloss: 0.210557
# [242]	train's binary_logloss: 0.0269159	valid's binary_logloss: 0.210645
# [243]	train's binary_logloss: 0.0266889	valid's binary_logloss: 0.210918
# [244]	train's binary_logloss: 0.0264774	valid's binary_logloss: 0.211207
# [245]	train's binary_logloss: 0.0262756	valid's binary_logloss: 0.211223
# [246]	train's binary_logloss: 0.0260543	valid's binary_logloss: 0.211317
# [247]	train's binary_logloss: 0.025848	valid's binary_logloss: 0.211445
# [248]	train's binary_logloss: 0.0256501	valid's binary_logloss: 0.211345
# [249]	train's binary_logloss: 0.0254541	valid's binary_logloss: 0.211276
# [250]	train's binary_logloss: 0.0252477	valid's binary_logloss: 0.21117
# [251]	train's binary_logloss: 0.0250747	valid's binary_logloss: 0.211481
# [252]	train's binary_logloss: 0.0248796	valid's binary_logloss: 0.211384
# [253]	train's binary_logloss: 0.0246765	valid's binary_logloss: 0.211452
# [254]	train's binary_logloss: 0.0244709	valid's binary_logloss: 0.21149
# [255]	train's binary_logloss: 0.0243025	valid's binary_logloss: 0.211749
# [256]	train's binary_logloss: 0.0240817	valid's binary_logloss: 0.211599
# [257]	train's binary_logloss: 0.0238982	valid's binary_logloss: 0.211586
# [258]	train's binary_logloss: 0.0236712	valid's binary_logloss: 0.211091
# [259]	train's binary_logloss: 0.0234694	valid's binary_logloss: 0.211001
# [260]	train's binary_logloss: 0.0232863	valid's binary_logloss: 0.210975
# [261]	train's binary_logloss: 0.0230658	valid's binary_logloss: 0.210987
# [262]	train's binary_logloss: 0.0228964	valid's binary_logloss: 0.211039
# [263]	train's binary_logloss: 0.0226739	valid's binary_logloss: 0.211118
# [264]	train's binary_logloss: 0.0224576	valid's binary_logloss: 0.210733
# [265]	train's binary_logloss: 0.0222902	valid's binary_logloss: 0.210694
# [266]	train's binary_logloss: 0.0221054	valid's binary_logloss: 0.210761
# [267]	train's binary_logloss: 0.02195	valid's binary_logloss: 0.210959
# [268]	train's binary_logloss: 0.0217939	valid's binary_logloss: 0.210866
# [269]	train's binary_logloss: 0.0216037	valid's binary_logloss: 0.211131
# [270]	train's binary_logloss: 0.0213941	valid's binary_logloss: 0.21108
# [271]	train's binary_logloss: 0.0212147	valid's binary_logloss: 0.211143
# [272]	train's binary_logloss: 0.0210458	valid's binary_logloss: 0.211308
# [273]	train's binary_logloss: 0.0208758	valid's binary_logloss: 0.211694
# [274]	train's binary_logloss: 0.0207162	valid's binary_logloss: 0.211772
# [275]	train's binary_logloss: 0.0205561	valid's binary_logloss: 0.211687
# [276]	train's binary_logloss: 0.0203968	valid's binary_logloss: 0.211642
# [277]	train's binary_logloss: 0.0202219	valid's binary_logloss: 0.211521
# [278]	train's binary_logloss: 0.020044	valid's binary_logloss: 0.211484
# [279]	train's binary_logloss: 0.0198912	valid's binary_logloss: 0.211666
# [280]	train's binary_logloss: 0.0197459	valid's binary_logloss: 0.21192
# [281]	train's binary_logloss: 0.0195532	valid's binary_logloss: 0.211532
# [282]	train's binary_logloss: 0.0194023	valid's binary_logloss: 0.211692
# [283]	train's binary_logloss: 0.0192691	valid's binary_logloss: 0.212135
# [284]	train's binary_logloss: 0.019121	valid's binary_logloss: 0.212054
# [285]	train's binary_logloss: 0.0189639	valid's binary_logloss: 0.212019
# [286]	train's binary_logloss: 0.0188352	valid's binary_logloss: 0.212391
# [287]	train's binary_logloss: 0.0187047	valid's binary_logloss: 0.212484
# [288]	train's binary_logloss: 0.0185548	valid's binary_logloss: 0.212748
# [289]	train's binary_logloss: 0.0184276	valid's binary_logloss: 0.213143
# [290]	train's binary_logloss: 0.0183122	valid's binary_logloss: 0.21277
# [291]	train's binary_logloss: 0.0181587	valid's binary_logloss: 0.212717
# [292]	train's binary_logloss: 0.0180099	valid's binary_logloss: 0.212823
# [293]	train's binary_logloss: 0.017889	valid's binary_logloss: 0.212986
# [294]	train's binary_logloss: 0.0177482	valid's binary_logloss: 0.213148
# [295]	train's binary_logloss: 0.0176188	valid's binary_logloss: 0.21322
# [296]	train's binary_logloss: 0.0174437	valid's binary_logloss: 0.212752
# [297]	train's binary_logloss: 0.0173029	valid's binary_logloss: 0.212584
# [298]	train's binary_logloss: 0.0171589	valid's binary_logloss: 0.212628
# [299]	train's binary_logloss: 0.0170213	valid's binary_logloss: 0.212708
# [300]	train's binary_logloss: 0.0168943	valid's binary_logloss: 0.212885
# logloss: 0.2129

# %%
pred
# Out:
# array([8.30069933e-02, 1.44318904e-02, 9.98427778e-04, ...,
#        9.34629531e-01, 4.14023216e-05, 3.12900280e-01])

# %% [markdown]
# ### early stopping導入版

# %%
# 学習の実行
# カテゴリ変数をパラメータで指定している
# バリデーションデータもモデルに渡し、学習の進行とともにスコアがどう変わるかモニタリングする
categorical_features = ['product', 'medical_info_b2', 'medical_info_b3']
model2 = lgb.train(params, lgb_train, num_boost_round=num_round,
                  categorical_feature=categorical_features,
                  valid_names=['train', 'valid'], valid_sets=[lgb_train, lgb_eval], early_stopping_rounds=10)

# バリデーションデータでのスコアの確認
va_pred = model2.predict(va_x)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# [1]	train's binary_logloss: 0.454286	valid's binary_logloss: 0.4654
# Training until validation scores don't improve for 10 rounds.
# [2]	train's binary_logloss: 0.429417	valid's binary_logloss: 0.443487
# [3]	train's binary_logloss: 0.410142	valid's binary_logloss: 0.426359
# [4]	train's binary_logloss: 0.393494	valid's binary_logloss: 0.411015
# [5]	train's binary_logloss: 0.379488	valid's binary_logloss: 0.398589
# [6]	train's binary_logloss: 0.366857	valid's binary_logloss: 0.386944
# [7]	train's binary_logloss: 0.354417	valid's binary_logloss: 0.376575
# [8]	train's binary_logloss: 0.34379	valid's binary_logloss: 0.367472
# [9]	train's binary_logloss: 0.334998	valid's binary_logloss: 0.359954
# [10]	train's binary_logloss: 0.325439	valid's binary_logloss: 0.35231
# [11]	train's binary_logloss: 0.316396	valid's binary_logloss: 0.345017
# [12]	train's binary_logloss: 0.309224	valid's binary_logloss: 0.340222
# [13]	train's binary_logloss: 0.301732	valid's binary_logloss: 0.333364
# [14]	train's binary_logloss: 0.294708	valid's binary_logloss: 0.328792
# [15]	train's binary_logloss: 0.288201	valid's binary_logloss: 0.324163
# [16]	train's binary_logloss: 0.282431	valid's binary_logloss: 0.319925
# [17]	train's binary_logloss: 0.276254	valid's binary_logloss: 0.315333
# [18]	train's binary_logloss: 0.271291	valid's binary_logloss: 0.312272
# [19]	train's binary_logloss: 0.265568	valid's binary_logloss: 0.308592
# [20]	train's binary_logloss: 0.260806	valid's binary_logloss: 0.305423
# [21]	train's binary_logloss: 0.256176	valid's binary_logloss: 0.302695
# [22]	train's binary_logloss: 0.251765	valid's binary_logloss: 0.300585
# [23]	train's binary_logloss: 0.247005	valid's binary_logloss: 0.29676
# [24]	train's binary_logloss: 0.242821	valid's binary_logloss: 0.294192
# [25]	train's binary_logloss: 0.23893	valid's binary_logloss: 0.291965
# [26]	train's binary_logloss: 0.234672	valid's binary_logloss: 0.288845
# [27]	train's binary_logloss: 0.230955	valid's binary_logloss: 0.286873
# [28]	train's binary_logloss: 0.227917	valid's binary_logloss: 0.284952
# [29]	train's binary_logloss: 0.22419	valid's binary_logloss: 0.282441
# [30]	train's binary_logloss: 0.220358	valid's binary_logloss: 0.279985
# [31]	train's binary_logloss: 0.216471	valid's binary_logloss: 0.276463
# [32]	train's binary_logloss: 0.213126	valid's binary_logloss: 0.274941
# [33]	train's binary_logloss: 0.209834	valid's binary_logloss: 0.27273
# [34]	train's binary_logloss: 0.206753	valid's binary_logloss: 0.271164
# [35]	train's binary_logloss: 0.204203	valid's binary_logloss: 0.269744
# [36]	train's binary_logloss: 0.200539	valid's binary_logloss: 0.266825
# [37]	train's binary_logloss: 0.197168	valid's binary_logloss: 0.265267
# [38]	train's binary_logloss: 0.194498	valid's binary_logloss: 0.263992
# [39]	train's binary_logloss: 0.192032	valid's binary_logloss: 0.263437
# [40]	train's binary_logloss: 0.189326	valid's binary_logloss: 0.261947
# [41]	train's binary_logloss: 0.186858	valid's binary_logloss: 0.260294
# [42]	train's binary_logloss: 0.18455	valid's binary_logloss: 0.259234
# [43]	train's binary_logloss: 0.181977	valid's binary_logloss: 0.257863
# [44]	train's binary_logloss: 0.179512	valid's binary_logloss: 0.256472
# [45]	train's binary_logloss: 0.177167	valid's binary_logloss: 0.255215
# [46]	train's binary_logloss: 0.174983	valid's binary_logloss: 0.254662
# [47]	train's binary_logloss: 0.172989	valid's binary_logloss: 0.254382
# [48]	train's binary_logloss: 0.170821	valid's binary_logloss: 0.253217
# [49]	train's binary_logloss: 0.168089	valid's binary_logloss: 0.251035
# [50]	train's binary_logloss: 0.16612	valid's binary_logloss: 0.250534
# [51]	train's binary_logloss: 0.164304	valid's binary_logloss: 0.249786
# [52]	train's binary_logloss: 0.162127	valid's binary_logloss: 0.24821
# [53]	train's binary_logloss: 0.160416	valid's binary_logloss: 0.247239
# [54]	train's binary_logloss: 0.158818	valid's binary_logloss: 0.246814
# [55]	train's binary_logloss: 0.156032	valid's binary_logloss: 0.244454
# [56]	train's binary_logloss: 0.154359	valid's binary_logloss: 0.243893
# [57]	train's binary_logloss: 0.152642	valid's binary_logloss: 0.243225
# [58]	train's binary_logloss: 0.151044	valid's binary_logloss: 0.242837
# [59]	train's binary_logloss: 0.149127	valid's binary_logloss: 0.241454
# [60]	train's binary_logloss: 0.146802	valid's binary_logloss: 0.239391
# [61]	train's binary_logloss: 0.145309	valid's binary_logloss: 0.238612
# [62]	train's binary_logloss: 0.143786	valid's binary_logloss: 0.238014
# [63]	train's binary_logloss: 0.142085	valid's binary_logloss: 0.236823
# [64]	train's binary_logloss: 0.140588	valid's binary_logloss: 0.236355
# [65]	train's binary_logloss: 0.138946	valid's binary_logloss: 0.235721
# [66]	train's binary_logloss: 0.137666	valid's binary_logloss: 0.235887
# [67]	train's binary_logloss: 0.135987	valid's binary_logloss: 0.235729
# [68]	train's binary_logloss: 0.134551	valid's binary_logloss: 0.235073
# [69]	train's binary_logloss: 0.133163	valid's binary_logloss: 0.234729
# [70]	train's binary_logloss: 0.131297	valid's binary_logloss: 0.233257
# [71]	train's binary_logloss: 0.12978	valid's binary_logloss: 0.232796
# [72]	train's binary_logloss: 0.128516	valid's binary_logloss: 0.232675
# [73]	train's binary_logloss: 0.12705	valid's binary_logloss: 0.232375
# [74]	train's binary_logloss: 0.12569	valid's binary_logloss: 0.231574
# [75]	train's binary_logloss: 0.124247	valid's binary_logloss: 0.230772
# [76]	train's binary_logloss: 0.122886	valid's binary_logloss: 0.229912
# [77]	train's binary_logloss: 0.121689	valid's binary_logloss: 0.229134
# [78]	train's binary_logloss: 0.120185	valid's binary_logloss: 0.227908
# [79]	train's binary_logloss: 0.119006	valid's binary_logloss: 0.227255
# [80]	train's binary_logloss: 0.117758	valid's binary_logloss: 0.226919
# [81]	train's binary_logloss: 0.116367	valid's binary_logloss: 0.226063
# [82]	train's binary_logloss: 0.115242	valid's binary_logloss: 0.225734
# [83]	train's binary_logloss: 0.114066	valid's binary_logloss: 0.225842
# [84]	train's binary_logloss: 0.113021	valid's binary_logloss: 0.225589
# [85]	train's binary_logloss: 0.111898	valid's binary_logloss: 0.22567
# [86]	train's binary_logloss: 0.110745	valid's binary_logloss: 0.225063
# [87]	train's binary_logloss: 0.109676	valid's binary_logloss: 0.225015
# [88]	train's binary_logloss: 0.10853	valid's binary_logloss: 0.225252
# [89]	train's binary_logloss: 0.107014	valid's binary_logloss: 0.223305
# [90]	train's binary_logloss: 0.105649	valid's binary_logloss: 0.222349
# [91]	train's binary_logloss: 0.10459	valid's binary_logloss: 0.221952
# [92]	train's binary_logloss: 0.103518	valid's binary_logloss: 0.221524
# [93]	train's binary_logloss: 0.102541	valid's binary_logloss: 0.221294
# [94]	train's binary_logloss: 0.101574	valid's binary_logloss: 0.221408
# [95]	train's binary_logloss: 0.100554	valid's binary_logloss: 0.221599
# [96]	train's binary_logloss: 0.0994329	valid's binary_logloss: 0.221159
# [97]	train's binary_logloss: 0.09839	valid's binary_logloss: 0.220885
# [98]	train's binary_logloss: 0.0974307	valid's binary_logloss: 0.22092
# [99]	train's binary_logloss: 0.0965374	valid's binary_logloss: 0.220945
# [100]	train's binary_logloss: 0.0956876	valid's binary_logloss: 0.221081
# [101]	train's binary_logloss: 0.0947192	valid's binary_logloss: 0.220654
# [102]	train's binary_logloss: 0.0937916	valid's binary_logloss: 0.220549
# [103]	train's binary_logloss: 0.0930301	valid's binary_logloss: 0.220399
# [104]	train's binary_logloss: 0.0920165	valid's binary_logloss: 0.219945
# [105]	train's binary_logloss: 0.0910464	valid's binary_logloss: 0.219687
# [106]	train's binary_logloss: 0.0901609	valid's binary_logloss: 0.21969
# [107]	train's binary_logloss: 0.0893582	valid's binary_logloss: 0.219252
# [108]	train's binary_logloss: 0.0885249	valid's binary_logloss: 0.218901
# [109]	train's binary_logloss: 0.0875383	valid's binary_logloss: 0.218721
# [110]	train's binary_logloss: 0.0866552	valid's binary_logloss: 0.218691
# [111]	train's binary_logloss: 0.0856867	valid's binary_logloss: 0.218664
# [112]	train's binary_logloss: 0.0849394	valid's binary_logloss: 0.218769
# [113]	train's binary_logloss: 0.0842242	valid's binary_logloss: 0.218774
# [114]	train's binary_logloss: 0.0830104	valid's binary_logloss: 0.217509
# [115]	train's binary_logloss: 0.0822351	valid's binary_logloss: 0.216948
# [116]	train's binary_logloss: 0.081499	valid's binary_logloss: 0.21661
# [117]	train's binary_logloss: 0.0807778	valid's binary_logloss: 0.216547
# [118]	train's binary_logloss: 0.0800547	valid's binary_logloss: 0.21671
# [119]	train's binary_logloss: 0.0792931	valid's binary_logloss: 0.216854
# [120]	train's binary_logloss: 0.0785995	valid's binary_logloss: 0.216721
# [121]	train's binary_logloss: 0.0777836	valid's binary_logloss: 0.216279
# [122]	train's binary_logloss: 0.0770291	valid's binary_logloss: 0.215768
# [123]	train's binary_logloss: 0.0763529	valid's binary_logloss: 0.215663
# [124]	train's binary_logloss: 0.0756929	valid's binary_logloss: 0.215824
# [125]	train's binary_logloss: 0.0748481	valid's binary_logloss: 0.215032
# [126]	train's binary_logloss: 0.0741879	valid's binary_logloss: 0.214879
# [127]	train's binary_logloss: 0.0736052	valid's binary_logloss: 0.214681
# [128]	train's binary_logloss: 0.0729446	valid's binary_logloss: 0.213922
# [129]	train's binary_logloss: 0.0722322	valid's binary_logloss: 0.213616
# [130]	train's binary_logloss: 0.0715016	valid's binary_logloss: 0.213133
# [131]	train's binary_logloss: 0.070899	valid's binary_logloss: 0.213395
# [132]	train's binary_logloss: 0.0702773	valid's binary_logloss: 0.213331
# [133]	train's binary_logloss: 0.0695678	valid's binary_logloss: 0.212686
# [134]	train's binary_logloss: 0.069043	valid's binary_logloss: 0.212414
# [135]	train's binary_logloss: 0.0684006	valid's binary_logloss: 0.212752
# [136]	train's binary_logloss: 0.0678648	valid's binary_logloss: 0.212819
# [137]	train's binary_logloss: 0.0672611	valid's binary_logloss: 0.21271
# [138]	train's binary_logloss: 0.0666838	valid's binary_logloss: 0.212938
# [139]	train's binary_logloss: 0.066072	valid's binary_logloss: 0.212569
# [140]	train's binary_logloss: 0.0655498	valid's binary_logloss: 0.212612
# [141]	train's binary_logloss: 0.0649604	valid's binary_logloss: 0.212542
# [142]	train's binary_logloss: 0.0643114	valid's binary_logloss: 0.212542
# [143]	train's binary_logloss: 0.0636712	valid's binary_logloss: 0.212273
# [144]	train's binary_logloss: 0.0630001	valid's binary_logloss: 0.211446
# [145]	train's binary_logloss: 0.0623817	valid's binary_logloss: 0.211248
# [146]	train's binary_logloss: 0.0618578	valid's binary_logloss: 0.211539
# [147]	train's binary_logloss: 0.0613503	valid's binary_logloss: 0.211277
# [148]	train's binary_logloss: 0.0607601	valid's binary_logloss: 0.210968
# [149]	train's binary_logloss: 0.0601986	valid's binary_logloss: 0.210897
# [150]	train's binary_logloss: 0.0595744	valid's binary_logloss: 0.210812
# [151]	train's binary_logloss: 0.059031	valid's binary_logloss: 0.21055
# [152]	train's binary_logloss: 0.0583743	valid's binary_logloss: 0.210196
# [153]	train's binary_logloss: 0.0578932	valid's binary_logloss: 0.210519
# [154]	train's binary_logloss: 0.0573391	valid's binary_logloss: 0.210795
# [155]	train's binary_logloss: 0.0568473	valid's binary_logloss: 0.210704
# [156]	train's binary_logloss: 0.0563098	valid's binary_logloss: 0.210547
# [157]	train's binary_logloss: 0.0558139	valid's binary_logloss: 0.210386
# [158]	train's binary_logloss: 0.0552833	valid's binary_logloss: 0.210318
# [159]	train's binary_logloss: 0.0548272	valid's binary_logloss: 0.210245
# [160]	train's binary_logloss: 0.0543163	valid's binary_logloss: 0.210311
# [161]	train's binary_logloss: 0.0538664	valid's binary_logloss: 0.210267
# [162]	train's binary_logloss: 0.0533857	valid's binary_logloss: 0.210163
# [163]	train's binary_logloss: 0.0529452	valid's binary_logloss: 0.210161
# [164]	train's binary_logloss: 0.0524996	valid's binary_logloss: 0.210123
# [165]	train's binary_logloss: 0.0519695	valid's binary_logloss: 0.210117
# [166]	train's binary_logloss: 0.0515136	valid's binary_logloss: 0.210138
# [167]	train's binary_logloss: 0.0510402	valid's binary_logloss: 0.210137
# [168]	train's binary_logloss: 0.0505055	valid's binary_logloss: 0.209715
# [169]	train's binary_logloss: 0.0500879	valid's binary_logloss: 0.209729
# [170]	train's binary_logloss: 0.0496811	valid's binary_logloss: 0.209841
# [171]	train's binary_logloss: 0.0492251	valid's binary_logloss: 0.209993
# [172]	train's binary_logloss: 0.0488387	valid's binary_logloss: 0.210273
# [173]	train's binary_logloss: 0.0483809	valid's binary_logloss: 0.210022
# [174]	train's binary_logloss: 0.0479534	valid's binary_logloss: 0.210315
# [175]	train's binary_logloss: 0.0475905	valid's binary_logloss: 0.210469
# [176]	train's binary_logloss: 0.0470586	valid's binary_logloss: 0.210253
# [177]	train's binary_logloss: 0.0467	valid's binary_logloss: 0.210233
# [178]	train's binary_logloss: 0.0463075	valid's binary_logloss: 0.210251
# Early stopping, best iteration is:
# [168]	train's binary_logloss: 0.0505055	valid's binary_logloss: 0.209715
# logloss: 0.2097

# %% [markdown]
# →アーリーストッピングが効いて168イテレーションで止まる

# %% [markdown]
# ### predictメソッドのnum_iteration引数に関する検証

# %% [markdown]
# #### 予測1：num_iterationでアーリーストッピングしたイテレーション数を指定

# %%
pred_with_best_iteration = model2.predict(test_x, num_iteration=model.best_iteration)
print(pred_with_best_iteration)
# Out:
# [1.17955551e-01 4.21639439e-02 5.44313703e-03 ... 8.33034274e-01
#  4.28464650e-04 3.68167940e-01]

# %% [markdown]
# #### 予測2：num_iterationはデフォルト値

# %%
# num_iterationはdefault=100のはずだが、指定しないときに何故かmodel.best_iterationを反映してる
pred = model2.predict(test_x)
print(pred)
# Out:
# [1.17955551e-01 4.21639439e-02 5.44313703e-03 ... 8.33034274e-01
#  4.28464650e-04 3.68167940e-01]

# %% [markdown]
# #### 予測1と予測2の結果が等しいことを検証

# %%
print(all([a==b for a, b in zip(pred, pred_with_best_iteration)]))
# Out:
# True

# %% [markdown]
# →等しい。num_iterationでmodel.best_iterationを指定しようがしまいが、結果は同じ。
